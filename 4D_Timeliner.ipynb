# %% [markdown]
# <a href="https://colab.research.google.com/github/gacevedob/Proyectos/blob/main/4D_Timeliner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install specklepy --upgrade
# Out:
# Requirement already satisfied: specklepy in /usr/local/lib/python3.10/dist-packages (2.21.2)
# Requirement already satisfied: Deprecated<2.0.0,>=1.2.13 in /usr/local/lib/python3.10/dist-packages (from specklepy) (1.2.15)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from specklepy) (1.4.4)
# Requirement already satisfied: attrs<24.0.0,>=23.1.0 in /usr/local/lib/python3.10/dist-packages (from specklepy) (23.2.0)
# Requirement already satisfied: gql<4.0.0,>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from gql[requests,websockets]<4.0.0,>=3.3.0->specklepy) (3.5.0)
# Requirement already satisfied: httpx<0.26.0,>=0.25.0 in /usr/local/lib/python3.10/dist-packages (from specklepy) (0.25.2)
# Requirement already satisfied: pydantic<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from specklepy) (2.10.3)
# Requirement already satisfied: stringcase<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from specklepy) (1.2.0)
# Requirement already satisfied: ujson<6.0.0,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from specklepy) (5.10.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated<2.0.0,>=1.2.13->specklepy) (1.17.0)
# Requirement already satisfied: graphql-core<3.3,>=3.2 in /usr/local/lib/python3.10/dist-packages (from gql<4.0.0,>=3.3.0->gql[requests,websockets]<4.0.0,>=3.3.0->specklepy) (3.2.5)
# Requirement already satisfied: yarl<2.0,>=1.6 in /usr/local/lib/python3.10/dist-packages (from gql<4.0.0,>=3.3.0->gql[requests,websockets]<4.0.0,>=3.3.0->specklepy) (1.18.3)
# Requirement already satisfied: backoff<3.0,>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from gql<4.0.0,>=3.3.0->gql[requests,websockets]<4.0.0,>=3.3.0->specklepy) (2.2.1)
# Requirement already satisfied: anyio<5,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gql<4.0.0,>=3.3.0->gql[requests,websockets]<4.0.0,>=3.3.0->specklepy) (3.7.1)
# Requirement already satisfied: requests<3,>=2.26 in /usr/local/lib/python3.10/dist-packages (from gql[requests,websockets]<4.0.0,>=3.3.0->specklepy) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gql[requests,websockets]<4.0.0,>=3.3.0->specklepy) (1.0.0)
# Requirement already satisfied: websockets<12,>=10 in /usr/local/lib/python3.10/dist-packages (from gql[requests,websockets]<4.0.0,>=3.3.0->specklepy) (11.0.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<0.26.0,>=0.25.0->specklepy) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<0.26.0,>=0.25.0->specklepy) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<0.26.0,>=0.25.0->specklepy) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<0.26.0,>=0.25.0->specklepy) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<0.26.0,>=0.25.0->specklepy) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0,>=2.5->specklepy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0,>=2.5->specklepy) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0,>=2.5->specklepy) (4.12.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.0->gql<4.0.0,>=3.3.0->gql[requests,websockets]<4.0.0,>=3.3.0->specklepy) (1.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.26->gql[requests,websockets]<4.0.0,>=3.3.0->specklepy) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.26->gql[requests,websockets]<4.0.0,>=3.3.0->specklepy) (2.2.3)
# Requirement already satisfied: multidict>=4.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.6->gql<4.0.0,>=3.3.0->gql[requests,websockets]<4.0.0,>=3.3.0->specklepy) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.6->gql<4.0.0,>=3.3.0->gql[requests,websockets]<4.0.0,>=3.3.0->specklepy) (0.2.1)

# %%
import requests
import pandas as pd

# Configuración general
HOST = "https://speckle.xyz/graphql"
TOKEN = "d59135bf7dada88ba2d3db54695f81606a7a6e86b0"

HEADERS = {
    "Authorization": f"Bearer {TOKEN}",
    "Content-Type": "application/json"
}

# %%
# Función para realizar consultas a Speckle
def make_speckle_query(query, variables):
    try:
        response = requests.post(HOST, json={"query": query, "variables": variables}, headers=HEADERS)
        response.raise_for_status()  # Lanza una excepción si la solicitud falla
        return response.json()
    except requests.RequestException as e:
        print(f"Error en la solicitud: {e}")
        return {}

# %%
# Consulta y variables
QUERY = """
query commit($projectId: String!, $objectId: String!, $limit: Int!) {
  project(id: $projectId) {
    object(id: $objectId) {
      children(limit: $limit) {
        objects {
          data
        }
      }
    }
  }
}
"""
VARIABLES = {
    "projectId": "bc02abaa2c",
    "objectId": "b421eb5d599db197fe8189589a0cad00",
    "limit": 10000
}

# %%
# Ejecutar la consulta
response = make_speckle_query(QUERY, VARIABLES)

# %%
# Extraer los datos relevantes
data = response.get("data", {}).get("project", {}).get("object", {}).get("children", {}).get("objects", [])

# Crear una lista para almacenar los resultados procesados
results = []

# %%
from datetime import datetime

# Función para convertir fechas al formato DD-MM-YYYY
def convertir_fecha(fecha):
    try:
        # Detectar y procesar la fecha solo si es válida
        if fecha:
            return datetime.strptime(fecha, "%Y-%m-%d").strftime("%d-%m-%Y")
    except ValueError:
        return fecha  # Si no es una fecha válida, se retorna como está
    return None

# Extraer y procesar los datos relevantes
def extract_results(data):
    results = []
    for obj in data:
        obj_data = obj.get("data", {})
        properties = obj_data.get("properties", {})
        elemento = properties.get("Elemento", {})
        componente = properties.get("Componente", {})
        timeliner = properties.get("TimeLiner", {})

        # Filtrar resultados con categoría no nula
        categoria = componente.get("Categoría")
        if categoria:
            results.append({
                "id": obj_data.get("id"),
                "Categoría": categoria,
                "Nivel": elemento.get("Capa"),
                "Tarea": timeliner.get("Contenido en tarea:1"),
                "Inicio Planeado": convertir_fecha(timeliner.get("Contenido en inicio de tarea (Planeada):1")),
                "Fin Planeado": convertir_fecha(timeliner.get("Contenido en fin de tarea (Planeada):1")),
                "Inicio Real": convertir_fecha(timeliner.get("Contenido en inicio de tarea (Real):1")),
                "Fin Real": convertir_fecha(timeliner.get("Contenido en fin de tarea (Real):1")),
            })
    return results

# Crear resultados
results = extract_results(data)

# Verificar los resultados
print(results[:5])  # Muestra los primeros 5 resultados procesados
# Out:
# [{'id': '0040953dd205001c3b9036ebdbd57be8', 'Categoría': 'Cimentación estructural', 'Nivel': '01 - Entry Level', 'Tarea': 'Encepado sector 1', 'Inicio Planeado': '09/28/2023 18:45:36', 'Fin Planeado': '10/20/2023 18:45:36', 'Inicio Real': '10/10/2023 18:45:36', 'Fin Real': '10/16/2023 18:45:36'}, {'id': '004dd62d2510b59825e5c214036d67aa', 'Categoría': 'Armazón estructural', 'Nivel': '02 - Floor', 'Tarea': 'Vigas sector 2', 'Inicio Planeado': '01/18/2024 16:43:12', 'Fin Planeado': '02/14/2024 10:01:48', 'Inicio Real': '01/30/2024 16:43:12', 'Fin Real': '02/13/2024 16:43:12'}, {'id': '00553356d130789ad2515b87ce51db63', 'Categoría': 'Cimentación estructural', 'Nivel': '01 - Entry Level', 'Tarea': 'Pilotes sector 1', 'Inicio Planeado': '09/11/2023 09:00:00', 'Fin Planeado': '09/28/2023 18:45:36', 'Inicio Real': '09/25/2023 09:00:00', 'Fin Real': '10/11/2023 19:00:00'}, {'id': '0097716adec52a81cfaad860c95430c1', 'Categoría': 'Armazón estructural', 'Nivel': '03 - Floor', 'Tarea': 'Vigas sector 2', 'Inicio Planeado': '04/04/2024 10:01:48', 'Fin Planeado': '05/03/2024 10:01:48', 'Inicio Real': None, 'Fin Real': None}, {'id': '00cb18cea3a78331cc821a929a1f8b52', 'Categoría': 'Cimentación estructural', 'Nivel': '01 - Entry Level', 'Tarea': 'Pilotes sector 4', 'Inicio Planeado': '09/11/2023 09:00:00', 'Fin Planeado': '09/27/2023 17:38:24', 'Inicio Real': '09/25/2023 09:00:00', 'Fin Real': '09/28/2023 19:00:00'}]

# %%
# Crear DataFrame
df = pd.DataFrame(results)

# Agregar columnas adicionales
projectId = "bc02abaa2c"
objectId = "b421eb5d599db197fe8189589a0cad00"
df["ModelURL"] = f"https://app.speckle.systems/streams/{projectId}"
df["VersionObjectId"] = objectId

# Verificar el DataFrame
print(df.head())
# Out:
#                                  id                Categoría  \
# 0  0040953dd205001c3b9036ebdbd57be8  Cimentación estructural
# 1  004dd62d2510b59825e5c214036d67aa      Armazón estructural
# 2  00553356d130789ad2515b87ce51db63  Cimentación estructural
# 3  0097716adec52a81cfaad860c95430c1      Armazón estructural
# 4  00cb18cea3a78331cc821a929a1f8b52  Cimentación estructural
#
#               Nivel              Tarea      Inicio Planeado  \
# 0  01 - Entry Level  Encepado sector 1  09/28/2023 18:45:36
# 1        02 - Floor     Vigas sector 2  01/18/2024 16:43:12
# 2  01 - Entry Level   Pilotes sector 1  09/11/2023 09:00:00
# 3        03 - Floor     Vigas sector 2  04/04/2024 10:01:48
# 4  01 - Entry Level   Pilotes sector 4  09/11/2023 09:00:00
#
#           Fin Planeado          Inicio Real             Fin Real  \
# 0  10/20/2023 18:45:36  10/10/2023 18:45:36  10/16/2023 18:45:36
# 1  02/14/2024 10:01:48  01/30/2024 16:43:12  02/13/2024 16:43:12
# 2  09/28/2023 18:45:36  09/25/2023 09:00:00  10/11/2023 19:00:00
# 3  05/03/2024 10:01:48                 None                 None
# 4  09/27/2023 17:38:24  09/25/2023 09:00:00  09/28/2023 19:00:00
#
#                                          ModelURL  \
# 0  https://app.speckle.systems/streams/bc02abaa2c
# 1  https://app.speckle.systems/streams/bc02abaa2c
# 2  https://app.speckle.systems/streams/bc02abaa2c
# 3  https://app.speckle.systems/streams/bc02abaa2c
# 4  https://app.speckle.systems/streams/bc02abaa2c
#
#                     VersionObjectId
# 0  b421eb5d599db197fe8189589a0cad00
# 1  b421eb5d599db197fe8189589a0cad00
# 2  b421eb5d599db197fe8189589a0cad00
# 3  b421eb5d599db197fe8189589a0cad00
# 4  b421eb5d599db197fe8189589a0cad00

# %%
# Ordenar el DataFrame por "Inicio Planeado"
df = df.sort_values("Inicio Planeado")

# Mostrar el DataFrame final
df
# Out:
#                                     id              Categoría       Nivel  \
# 586   49b40864aaea3a1fbe61faca346ff49b    Armazón estructural  03 - Floor
# 1637  d0b3bd2afbe7ecde7391c2bcd131cfc0    Armazón estructural  03 - Floor
# 1635  d035eeb27bd9e6cbebcab9e344cbd040    Armazón estructural  03 - Floor
# 151   1358e43ba985702fea123da6d8442c34    Armazón estructural  03 - Floor
# 1521  c26c969ed9fa2bf70af3ad18493a4d69    Armazón estructural  03 - Floor
# ...                                ...                    ...         ...
# 806   6810e4c5a35bdf477c30ff9bd60e3d77  Pilares estructurales  02 - Floor
# 517   41e3f8308564166bd22ed76ac0b3372c  Pilares estructurales  02 - Floor
# 1160  92429cb09a0a831e1215362beb3440c0  Pilares estructurales  02 - Floor
# 781   6507cdcf0d7780c7dae773bb2542ce6b  Pilares estructurales  02 - Floor
# 706   5b77b6172c232d9df469354767828075  Pilares estructurales  02 - Floor
#
#                  Tarea      Inicio Planeado         Fin Planeado  \
# 586     Vigas sector 1  01/10/2024 17:34:48  01/26/2024 17:34:48
# 1637    Vigas sector 1  01/10/2024 17:34:48  01/26/2024 17:34:48
# 1635    Vigas sector 1  01/10/2024 17:34:48  01/26/2024 17:34:48
# 151     Vigas sector 1  01/10/2024 17:34:48  01/26/2024 17:34:48
# 1521    Vigas sector 1  01/10/2024 17:34:48  01/26/2024 17:34:48
# ...                ...                  ...                  ...
# 806   Pilares sector 1  12/26/2023 17:34:48  01/10/2024 17:34:48
# 517   Pilares sector 1  12/26/2023 17:34:48  01/10/2024 17:34:48
# 1160  Pilares sector 1  12/26/2023 17:34:48  01/10/2024 17:34:48
# 781   Pilares sector 1  12/26/2023 17:34:48  01/10/2024 17:34:48
# 706   Pilares sector 1  12/26/2023 17:34:48  01/10/2024 17:34:48
#
#               Inicio Real             Fin Real  \
# 586                  None                 None
# 1637                 None                 None
# 1635                 None                 None
# 151                  None                 None
# 1521                 None                 None
# ...                   ...                  ...
# 806   01/02/2024 17:34:48  01/17/2024 17:34:48
# 517   01/02/2024 17:34:48  01/17/2024 17:34:48
# 1160  01/02/2024 17:34:48  01/17/2024 17:34:48
# 781   01/02/2024 17:34:48  01/17/2024 17:34:48
# 706   01/02/2024 17:34:48  01/17/2024 17:34:48
#
#                                             ModelURL  \
# 586   https://app.speckle.systems/streams/bc02abaa2c
# 1637  https://app.speckle.systems/streams/bc02abaa2c
# 1635  https://app.speckle.systems/streams/bc02abaa2c
# 151   https://app.speckle.systems/streams/bc02abaa2c
# 1521  https://app.speckle.systems/streams/bc02abaa2c
# ...                                              ...
# 806   https://app.speckle.systems/streams/bc02abaa2c
# 517   https://app.speckle.systems/streams/bc02abaa2c
# 1160  https://app.speckle.systems/streams/bc02abaa2c
# 781   https://app.speckle.systems/streams/bc02abaa2c
# 706   https://app.speckle.systems/streams/bc02abaa2c
#
#                        VersionObjectId
# 586   b421eb5d599db197fe8189589a0cad00
# 1637  b421eb5d599db197fe8189589a0cad00
# 1635  b421eb5d599db197fe8189589a0cad00
# 151   b421eb5d599db197fe8189589a0cad00
# 1521  b421eb5d599db197fe8189589a0cad00
# ...                                ...
# 806   b421eb5d599db197fe8189589a0cad00
# 517   b421eb5d599db197fe8189589a0cad00
# 1160  b421eb5d599db197fe8189589a0cad00
# 781   b421eb5d599db197fe8189589a0cad00
# 706   b421eb5d599db197fe8189589a0cad00
#
# [2009 rows x 10 columns]

# %%
# --- Google Sheets Integration ---
from google.colab import auth
from googleapiclient.discovery import build
import time

# %%
from google.colab import auth
from googleapiclient.discovery import build

# Autenticar el acceso a la API de Google Sheets
auth.authenticate_user()

# Crear el servicio de Google Sheets API
service = build('sheets', 'v4')

# ID del libro de Google Sheets 'Timeliner_4D_Data' (reemplaza este ID con el real de tu libro)
spreadsheet_id = '1muBCs590gVkqbWtO1xTXP-rsMrPaJoj82IlcT0WLqVg'  # Reemplázalo con el ID de tu libro 'Timeliner_4D_Data'

# Convertir el DataFrame a una lista de listas (formato que requiere Google Sheets)
values = df.values.tolist()

# Agregar los encabezados (nombres de las columnas) como la primera fila
encabezados = df.columns.tolist()
values.insert(0, encabezados)  # Inserta los encabezados como la primera fila

# Nombre de la hoja será el objectId
nombre_hoja = f"{objectId}"

# Obtener las hojas existentes del libro
spreadsheet = service.spreadsheets().get(spreadsheetId=spreadsheet_id).execute()
sheets = spreadsheet.get('sheets', [])

# Verificar si la hoja con el objectId ya existe
hoja_existente = False
for sheet in sheets:
    if sheet['properties']['title'] == nombre_hoja:
        hoja_existente = True
        break

if hoja_existente:
    # Si la hoja ya existe, actualizamos los datos en lugar de crearla
    service.spreadsheets().values().update(
        spreadsheetId=spreadsheet_id,
        range=f"{nombre_hoja}!A1",  # Especifica la celda donde comenzar a escribir
        valueInputOption="RAW",
        body={"values": values}
    ).execute()

    print(f"Datos actualizados en la hoja '{nombre_hoja}' en el libro '{spreadsheet_id}'.")
else:
    # Si la hoja no existe, la creamos
    add_sheet_request = {
        "requests": [
            {
                "addSheet": {
                    "properties": {
                        "title": nombre_hoja  # Título de la nueva hoja
                    }
                }
            }
        ]
    }

    # Crear la nueva hoja
    service.spreadsheets().batchUpdate(
        spreadsheetId=spreadsheet_id,
        body=add_sheet_request
    ).execute()

    # Escribir los datos en la nueva hoja
    service.spreadsheets().values().update(
        spreadsheetId=spreadsheet_id,
        range=f"{nombre_hoja}!A1",  # Especifica la celda donde comenzar a escribir
        valueInputOption="RAW",
        body={"values": values}
    ).execute()

    print(f"Hoja '{nombre_hoja}' creada y datos escritos en el libro '{spreadsheet_id}'.")
# Out:
# Datos actualizados en la hoja 'b421eb5d599db197fe8189589a0cad00' en el libro '1muBCs590gVkqbWtO1xTXP-rsMrPaJoj82IlcT0WLqVg'.
